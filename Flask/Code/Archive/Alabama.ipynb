# %%
import pandas as pd

# %%
df = pd.read_csv("alabama.csv")

# %%
list(df.columns)
# Out:
# ['Mobility status (lived here 1 year ago) (MIG)',
#  'Total',
#  'N/A (person less than 1 year old/lived in same house 1 year ago)',
#  'Alabama/AL',
#  'Alaska/AK',
#  'Arizona/AZ',
#  'Arkansas/AR',
#  'California/CA',
#  'Colorado/CO',
#  'Connecticut/CT',
#  'Delaware/DE',
#  'District of Columbia/DC',
#  'Florida/FL',
#  'Georgia/GA',
#  'Hawaii/HI',
#  'Idaho/ID',
#  'Illinois/IL',
#  'Indiana/IN',
#  'Iowa/IA',
#  'Kansas/KS',
#  'Kentucky/KY',
#  'Louisiana/LA',
#  'Maine/ME',
#  'Maryland/MD',
#  'Massachusetts/MA',
#  'Michigan/MI',
#  'Minnesota/MN',
#  'Mississippi/MS',
#  'Missouri/MO',
#  'Montana/MT',
#  'Nebraska/NE',
#  'Nevada/NV',
#  'New Hampshire/NH',
#  'New Jersey/NJ',
#  'New Mexico/NM',
#  'New York/NY',
#  'North Carolina/NC',
#  'North Dakota/ND',
#  'Ohio/OH',
#  'Oklahoma/OK',
#  'Oregon/OR',
#  'Pennsylvania/PA',
#  'Rhode Island/RI',
#  'South Carolina/SC',
#  'South Dakota/SD',
#  'Tennessee/TN',
#  'Texas/TX',
#  'Utah/UT',
#  'Vermont/VT',
#  'Virginia/VA',
#  'Washington/WA',
#  'West Virginia/WV',
#  'Wisconsin/WI',
#  'Wyoming/WY',
#  'Puerto Rico',
#  'France',
#  'Germany',
#  'Northern Europe, Not Specified',
#  'Eastern Europe, Not Specified',
#  'Western Europe or Other Europe, Not Specified',
#  'Italy',
#  'Spain',
#  'United Kingdom, Excluding England',
#  'England',
#  'Russia',
#  'Ukraine (2017 or later)',
#  'Afghanistan',
#  'China, Hong Kong, Macau and Paracel Islands',
#  'India',
#  'Iraq (2016 or earlier)',
#  'Israel (2017 or later)',
#  'Japan',
#  'Korea',
#  'Nepal',
#  'Pakistan',
#  'Philippines',
#  'Saudi Arabia',
#  'Taiwan',
#  'Thailand',
#  'Turkey',
#  'United Arab Emirates (2017 or later)',
#  'Vietnam',
#  'Eastern Asia, Not Specified',
#  'Western Asia, Not Specified',
#  'South Central Asia or Asia, Not Specified',
#  'Canada',
#  'Mexico',
#  'El Salvador',
#  'Guatemala',
#  'Honduras',
#  'Central America, Not Specified',
#  'Cuba',
#  'Dominican Republic',
#  'Haiti',
#  'Jamaica',
#  'Caribbean and North America, Not Specified',
#  'Brazil',
#  'Colombia',
#  'Ecuador (2017 or later)',
#  'Peru (2017 or later)',
#  'Venezuela (2017 or later)',
#  'South America, Not Specified',
#  'Egypt',
#  'Ethiopia (2017 or later)',
#  'Kenya (2017 or later)',
#  'Nigeria',
#  'Western Africa, Not Specified',
#  'Northern Africa or Other Africa, Not Specified',
#  'Eastern Africa, Not Specified',
#  'Australia',
#  'Other US Island Areas, Oceania, Not Specified, or At Sea']

# %%
df.columns = ['Mobility_status',
 'Total',
 'N/A (person less than 1 year old/lived in same house 1 year ago)',
 'Alabama/AL',
 'Alaska/AK',
 'Arizona/AZ',
 'Arkansas/AR',
 'California/CA',
 'Colorado/CO',
 'Connecticut/CT',
 'Delaware/DE',
 'District of Columbia/DC',
 'Florida/FL',
 'Georgia/GA',
 'Hawaii/HI',
 'Idaho/ID',
 'Illinois/IL',
 'Indiana/IN',
 'Iowa/IA',
 'Kansas/KS',
 'Kentucky/KY',
 'Louisiana/LA',
 'Maine/ME',
 'Maryland/MD',
 'Massachusetts/MA',
 'Michigan/MI',
 'Minnesota/MN',
 'Mississippi/MS',
 'Missouri/MO',
 'Montana/MT',
 'Nebraska/NE',
 'Nevada/NV',
 'New Hampshire/NH',
 'New Jersey/NJ',
 'New Mexico/NM',
 'New York/NY',
 'North Carolina/NC',
 'North Dakota/ND',
 'Ohio/OH',
 'Oklahoma/OK',
 'Oregon/OR',
 'Pennsylvania/PA',
 'Rhode Island/RI',
 'South Carolina/SC',
 'South Dakota/SD',
 'Tennessee/TN',
 'Texas/TX',
 'Utah/UT',
 'Vermont/VT',
 'Virginia/VA',
 'Washington/WA',
 'West Virginia/WV',
 'Wisconsin/WI',
 'Wyoming/WY',
 'Puerto Rico',
 'France',
 'Germany',
 'Northern Europe, Not Specified',
 'Eastern Europe, Not Specified',
 'Western Europe or Other Europe, Not Specified',
 'Italy',
 'Spain',
 'United Kingdom, Excluding England',
 'England',
 'Russia',
 'Ukraine (2017 or later)',
 'Afghanistan',
 'China, Hong Kong, Macau and Paracel Islands',
 'India',
 'Iraq (2016 or earlier)',
 'Israel (2017 or later)',
 'Japan',
 'Korea',
 'Nepal',
 'Pakistan',
 'Philippines',
 'Saudi Arabia',
 'Taiwan',
 'Thailand',
 'Turkey',
 'United Arab Emirates (2017 or later)',
 'Vietnam',
 'Eastern Asia, Not Specified',
 'Western Asia, Not Specified',
 'South Central Asia or Asia, Not Specified',
 'Canada',
 'Mexico',
 'El Salvador',
 'Guatemala',
 'Honduras',
 'Central America, Not Specified',
 'Cuba',
 'Dominican Republic',
 'Haiti',
 'Jamaica',
 'Caribbean and North America, Not Specified',
 'Brazil',
 'Colombia',
 'Ecuador (2017 or later)',
 'Peru (2017 or later)',
 'Venezuela (2017 or later)',
 'South America, Not Specified',
 'Egypt',
 'Ethiopia (2017 or later)',
 'Kenya (2017 or later)',
 'Nigeria',
 'Western Africa, Not Specified',
 'Northern Africa or Other Africa, Not Specified',
 'Eastern Africa, Not Specified',
 'Australia',
 'Other US Island Areas, Oceania, Not Specified, or At Sea']

# %%
df = df.set_index("Mobility_status")
df
# Out:
#                                                       Total  \
# Mobility_status
#  -> Total                                           4876250
#  -> Total -> Total Alabama                          4876250
#  -> Total -> Total Alabama -> Total N/A (less t...   170882
# N/A(less than 1 year old)                             56700
# Yes, same house (nonmovers)                           90139
# ...                                                     ...
#  -> Total -> Total Alabama -> Total Doctorate d...    35969
# N/A(less than 1 year old)                                 0
# Yes, same house (nonmovers)                           31987
# No, outside US and Puerto Rico                          270
# No, different house in US or Puerto Rico               3712
#
#                                                     N/A (person less than 1 year old/lived in same house 1 year ago)  \
# Mobility_status
#  -> Total                                                                                     4209655
#  -> Total -> Total Alabama                                                                    4209655
#  -> Total -> Total Alabama -> Total N/A (less t...                                             146839
# N/A(less than 1 year old)                                                                       56700
# Yes, same house (nonmovers)                                                                     90139
# ...                                                                                               ...
#  -> Total -> Total Alabama -> Total Doctorate d...                                              31987
# N/A(less than 1 year old)                                                                           0
# Yes, same house (nonmovers)                                                                     31987
# No, outside US and Puerto Rico                                                                      0
# No, different house in US or Puerto Rico                                                            0
#
#                                                     Alabama/AL  Alaska/AK  \
# Mobility_status
#  -> Total                                               539940        669
#  -> Total -> Total Alabama                              539940        669
#  -> Total -> Total Alabama -> Total N/A (less t...       20031         78
# N/A(less than 1 year old)                                    0          0
# Yes, same house (nonmovers)                                  0          0
# ...                                                        ...        ...
#  -> Total -> Total Alabama -> Total Doctorate d...        2335          0
# N/A(less than 1 year old)                                    0          0
# Yes, same house (nonmovers)                                  0          0
# No, outside US and Puerto Rico                               0          0
# No, different house in US or Puerto Rico                  2335          0
#
#                                                     Arizona/AZ  Arkansas/AR  \
# Mobility_status
#  -> Total                                                 1317         1227
#  -> Total -> Total Alabama                                1317         1227
#  -> Total -> Total Alabama -> Total N/A (less t...          31           73
# N/A(less than 1 year old)                                    0            0
# Yes, same house (nonmovers)                                  0            0
# ...                                                        ...          ...
#  -> Total -> Total Alabama -> Total Doctorate d...           0           26
# N/A(less than 1 year old)                                    0            0
# Yes, same house (nonmovers)                                  0            0
# No, outside US and Puerto Rico                               0            0
# No, different house in US or Puerto Rico                     0           26
#
#                                                     California/CA  \
# Mobility_status
#  -> Total                                                    3163
#  -> Total -> Total Alabama                                   3163
#  -> Total -> Total Alabama -> Total N/A (less t...             76
# N/A(less than 1 year old)                                       0
# Yes, same house (nonmovers)                                     0
# ...                                                           ...
#  -> Total -> Total Alabama -> Total Doctorate d...             14
# N/A(less than 1 year old)                                       0
# Yes, same house (nonmovers)                                     0
# No, outside US and Puerto Rico                                  0
# No, different house in US or Puerto Rico                       14
#
#                                                     Colorado/CO  \
# Mobility_status
#  -> Total                                                  1777
#  -> Total -> Total Alabama                                 1777
#  -> Total -> Total Alabama -> Total N/A (less t...           91
# N/A(less than 1 year old)                                     0
# Yes, same house (nonmovers)                                   0
# ...                                                         ...
#  -> Total -> Total Alabama -> Total Doctorate d...           10
# N/A(less than 1 year old)                                     0
# Yes, same house (nonmovers)                                   0
# No, outside US and Puerto Rico                                0
# No, different house in US or Puerto Rico                     10
#
#                                                     Connecticut/CT  \
# Mobility_status
#  -> Total                                                      618
#  -> Total -> Total Alabama                                     618
#  -> Total -> Total Alabama -> Total N/A (less t...               0
# N/A(less than 1 year old)                                        0
# Yes, same house (nonmovers)                                      0
# ...                                                            ...
#  -> Total -> Total Alabama -> Total Doctorate d...               0
# N/A(less than 1 year old)                                        0
# Yes, same house (nonmovers)                                      0
# No, outside US and Puerto Rico                                   0
# No, different house in US or Puerto Rico                         0
#
#                                                     Delaware/DE  ...  \
# Mobility_status                                                  ...
#  -> Total                                                   168  ...
#  -> Total -> Total Alabama                                  168  ...
#  -> Total -> Total Alabama -> Total N/A (less t...            0  ...
# N/A(less than 1 year old)                                     0  ...
# Yes, same house (nonmovers)                                   0  ...
# ...                                                         ...  ...
#  -> Total -> Total Alabama -> Total Doctorate d...            0  ...
# N/A(less than 1 year old)                                     0  ...
# Yes, same house (nonmovers)                                   0  ...
# No, outside US and Puerto Rico                                0  ...
# No, different house in US or Puerto Rico                      0  ...
#
#                                                     South America, Not Specified  \
# Mobility_status
#  -> Total                                                                    514
#  -> Total -> Total Alabama                                                   514
#  -> Total -> Total Alabama -> Total N/A (less t...                           179
# N/A(less than 1 year old)                                                      0
# Yes, same house (nonmovers)                                                    0
# ...                                                                          ...
#  -> Total -> Total Alabama -> Total Doctorate d...                             0
# N/A(less than 1 year old)                                                      0
# Yes, same house (nonmovers)                                                    0
# No, outside US and Puerto Rico                                                 0
# No, different house in US or Puerto Rico                                       0
#
#                                                     Egypt  \
# Mobility_status
#  -> Total                                              41
#  -> Total -> Total Alabama                             41
#  -> Total -> Total Alabama -> Total N/A (less t...      0
# N/A(less than 1 year old)                               0
# Yes, same house (nonmovers)                             0
# ...                                                   ...
#  -> Total -> Total Alabama -> Total Doctorate d...      0
# N/A(less than 1 year old)                               0
# Yes, same house (nonmovers)                             0
# No, outside US and Puerto Rico                          0
# No, different house in US or Puerto Rico                0
#
#                                                     Ethiopia (2017 or later)  \
# Mobility_status
#  -> Total                                                                  0
#  -> Total -> Total Alabama                                                 0
#  -> Total -> Total Alabama -> Total N/A (less t...                         0
# N/A(less than 1 year old)                                                  0
# Yes, same house (nonmovers)                                                0
# ...                                                                      ...
#  -> Total -> Total Alabama -> Total Doctorate d...                         0
# N/A(less than 1 year old)                                                  0
# Yes, same house (nonmovers)                                                0
# No, outside US and Puerto Rico                                             0
# No, different house in US or Puerto Rico                                   0
#
#                                                     Kenya (2017 or later)  \
# Mobility_status
#  -> Total                                                              49
#  -> Total -> Total Alabama                                             49
#  -> Total -> Total Alabama -> Total N/A (less t...                      0
# N/A(less than 1 year old)                                               0
# Yes, same house (nonmovers)                                             0
# ...                                                                   ...
#  -> Total -> Total Alabama -> Total Doctorate d...                      0
# N/A(less than 1 year old)                                               0
# Yes, same house (nonmovers)                                             0
# No, outside US and Puerto Rico                                          0
# No, different house in US or Puerto Rico                                0
#
#                                                     Nigeria  \
# Mobility_status
#  -> Total                                               173
#  -> Total -> Total Alabama                              173
#  -> Total -> Total Alabama -> Total N/A (less t...        0
# N/A(less than 1 year old)                                 0
# Yes, same house (nonmovers)                               0
# ...                                                     ...
#  -> Total -> Total Alabama -> Total Doctorate d...        0
# N/A(less than 1 year old)                                 0
# Yes, same house (nonmovers)                               0
# No, outside US and Puerto Rico                            0
# No, different house in US or Puerto Rico                  0
#
#                                                     Western Africa, Not Specified  \
# Mobility_status
#  -> Total                                                                      36
#  -> Total -> Total Alabama                                                     36
#  -> Total -> Total Alabama -> Total N/A (less t...                              0
# N/A(less than 1 year old)                                                       0
# Yes, same house (nonmovers)                                                     0
# ...                                                                           ...
#  -> Total -> Total Alabama -> Total Doctorate d...                              0
# N/A(less than 1 year old)                                                       0
# Yes, same house (nonmovers)                                                     0
# No, outside US and Puerto Rico                                                  0
# No, different house in US or Puerto Rico                                        0
#
#                                                     Northern Africa or Other Africa, Not Specified  \
# Mobility_status
#  -> Total                                                                                      150
#  -> Total -> Total Alabama                                                                     150
#  -> Total -> Total Alabama -> Total N/A (less t...                                               0
# N/A(less than 1 year old)                                                                        0
# Yes, same house (nonmovers)                                                                      0
# ...                                                                                            ...
#  -> Total -> Total Alabama -> Total Doctorate d...                                               0
# N/A(less than 1 year old)                                                                        0
# Yes, same house (nonmovers)                                                                      0
# No, outside US and Puerto Rico                                                                   0
# No, different house in US or Puerto Rico                                                         0
#
#                                                     Eastern Africa, Not Specified  \
# Mobility_status
#  -> Total                                                                     208
#  -> Total -> Total Alabama                                                    208
#  -> Total -> Total Alabama -> Total N/A (less t...                              0
# N/A(less than 1 year old)                                                       0
# Yes, same house (nonmovers)                                                     0
# ...                                                                           ...
#  -> Total -> Total Alabama -> Total Doctorate d...                              0
# N/A(less than 1 year old)                                                       0
# Yes, same house (nonmovers)                                                     0
# No, outside US and Puerto Rico                                                  0
# No, different house in US or Puerto Rico                                        0
#
#                                                     Australia  \
# Mobility_status
#  -> Total                                                 151
#  -> Total -> Total Alabama                                151
#  -> Total -> Total Alabama -> Total N/A (less t...         20
# N/A(less than 1 year old)                                   0
# Yes, same house (nonmovers)                                 0
# ...                                                       ...
#  -> Total -> Total Alabama -> Total Doctorate d...         10
# N/A(less than 1 year old)                                   0
# Yes, same house (nonmovers)                                 0
# No, outside US and Puerto Rico                             10
# No, different house in US or Puerto Rico                    0
#
#                                                     Other US Island Areas, Oceania, Not Specified, or At Sea
# Mobility_status
#  -> Total                                                                                         170
#  -> Total -> Total Alabama                                                                        170
#  -> Total -> Total Alabama -> Total N/A (less t...                                                  0
# N/A(less than 1 year old)                                                                           0
# Yes, same house (nonmovers)                                                                         0
# ...                                                                                               ...
#  -> Total -> Total Alabama -> Total Doctorate d...                                                  0
# N/A(less than 1 year old)                                                                           0
# Yes, same house (nonmovers)                                                                         0
# No, outside US and Puerto Rico                                                                      0
# No, different house in US or Puerto Rico                                                            0
#
# [127 rows x 110 columns]

# %%
df2 = df.T

# %%
df2["To_State"] = "Alabama"

# %%
df2
# Out:
# Mobility_status                                      -> Total  \
# Total                                                 4876250
# N/A (person less than 1 year old/lived in same ...    4209655
# Alabama/AL                                             539940
# Alaska/AK                                                 669
# Arizona/AZ                                               1317
# ...                                                       ...
# Western Africa, Not Specified                              36
# Northern Africa or Other Africa, Not Specified            150
# Eastern Africa, Not Specified                             208
# Australia                                                 151
# Other US Island Areas, Oceania, Not Specified, ...        170
#
# Mobility_status                                      -> Total -> Total Alabama  \
# Total                                                                  4876250
# N/A (person less than 1 year old/lived in same ...                     4209655
# Alabama/AL                                                              539940
# Alaska/AK                                                                  669
# Arizona/AZ                                                                1317
# ...                                                                        ...
# Western Africa, Not Specified                                               36
# Northern Africa or Other Africa, Not Specified                             150
# Eastern Africa, Not Specified                                              208
# Australia                                                                  151
# Other US Island Areas, Oceania, Not Specified, ...                         170
#
# Mobility_status                                      -> Total -> Total Alabama -> Total N/A (less than 3 years old)  \
# Total                                                                                          170882
# N/A (person less than 1 year old/lived in same ...                                             146839
# Alabama/AL                                                                                      20031
# Alaska/AK                                                                                          78
# Arizona/AZ                                                                                         31
# ...                                                                                               ...
# Western Africa, Not Specified                                                                       0
# Northern Africa or Other Africa, Not Specified                                                      0
# Eastern Africa, Not Specified                                                                       0
# Australia                                                                                          20
# Other US Island Areas, Oceania, Not Specified, ...                                                  0
#
# Mobility_status                                     N/A(less than 1 year old)  \
# Total                                                                   56700
# N/A (person less than 1 year old/lived in same ...                      56700
# Alabama/AL                                                                  0
# Alaska/AK                                                                   0
# Arizona/AZ                                                                  0
# ...                                                                       ...
# Western Africa, Not Specified                                               0
# Northern Africa or Other Africa, Not Specified                              0
# Eastern Africa, Not Specified                                               0
# Australia                                                                   0
# Other US Island Areas, Oceania, Not Specified, ...                          0
#
# Mobility_status                                     Yes, same house (nonmovers)  \
# Total                                                                     90139
# N/A (person less than 1 year old/lived in same ...                        90139
# Alabama/AL                                                                    0
# Alaska/AK                                                                     0
# Arizona/AZ                                                                    0
# ...                                                                         ...
# Western Africa, Not Specified                                                 0
# Northern Africa or Other Africa, Not Specified                                0
# Eastern Africa, Not Specified                                                 0
# Australia                                                                     0
# Other US Island Areas, Oceania, Not Specified, ...                            0
#
# Mobility_status                                     No, outside US and Puerto Rico  \
# Total                                                                          368
# N/A (person less than 1 year old/lived in same ...                               0
# Alabama/AL                                                                       0
# Alaska/AK                                                                        0
# Arizona/AZ                                                                       0
# ...                                                                            ...
# Western Africa, Not Specified                                                    0
# Northern Africa or Other Africa, Not Specified                                   0
# Eastern Africa, Not Specified                                                    0
# Australia                                                                       20
# Other US Island Areas, Oceania, Not Specified, ...                               0
#
# Mobility_status                                     No, different house in US or Puerto Rico  \
# Total                                                                                  23675
# N/A (person less than 1 year old/lived in same ...                                         0
# Alabama/AL                                                                             20031
# Alaska/AK                                                                                 78
# Arizona/AZ                                                                                31
# ...                                                                                      ...
# Western Africa, Not Specified                                                              0
# Northern Africa or Other Africa, Not Specified                                             0
# Eastern Africa, Not Specified                                                              0
# Australia                                                                                  0
# Other US Island Areas, Oceania, Not Specified, ...                                         0
#
# Mobility_status                                      -> Total -> Total Alabama -> Total No schooling completed  \
# Total                                                                                          163080
# N/A (person less than 1 year old/lived in same ...                                             134290
# Alabama/AL                                                                                      24017
# Alaska/AK                                                                                          30
# Arizona/AZ                                                                                        105
# ...                                                                                               ...
# Western Africa, Not Specified                                                                       0
# Northern Africa or Other Africa, Not Specified                                                      0
# Eastern Africa, Not Specified                                                                      37
# Australia                                                                                           9
# Other US Island Areas, Oceania, Not Specified, ...                                                  0
#
# Mobility_status                                     N/A(less than 1 year old)  \
# Total                                                                       0
# N/A (person less than 1 year old/lived in same ...                          0
# Alabama/AL                                                                  0
# Alaska/AK                                                                   0
# Arizona/AZ                                                                  0
# ...                                                                       ...
# Western Africa, Not Specified                                               0
# Northern Africa or Other Africa, Not Specified                              0
# Eastern Africa, Not Specified                                               0
# Australia                                                                   0
# Other US Island Areas, Oceania, Not Specified, ...                          0
#
# Mobility_status                                     Yes, same house (nonmovers)  \
# Total                                                                    134290
# N/A (person less than 1 year old/lived in same ...                       134290
# Alabama/AL                                                                    0
# Alaska/AK                                                                     0
# Arizona/AZ                                                                    0
# ...                                                                         ...
# Western Africa, Not Specified                                                 0
# Northern Africa or Other Africa, Not Specified                                0
# Eastern Africa, Not Specified                                                 0
# Australia                                                                     0
# Other US Island Areas, Oceania, Not Specified, ...                            0
#
# Mobility_status                                     ...  \
# Total                                               ...
# N/A (person less than 1 year old/lived in same ...  ...
# Alabama/AL                                          ...
# Alaska/AK                                           ...
# Arizona/AZ                                          ...
# ...                                                 ...
# Western Africa, Not Specified                       ...
# Northern Africa or Other Africa, Not Specified      ...
# Eastern Africa, Not Specified                       ...
# Australia                                           ...
# Other US Island Areas, Oceania, Not Specified, ...  ...
#
# Mobility_status                                     N/A(less than 1 year old)  \
# Total                                                                       0
# N/A (person less than 1 year old/lived in same ...                          0
# Alabama/AL                                                                  0
# Alaska/AK                                                                   0
# Arizona/AZ                                                                  0
# ...                                                                       ...
# Western Africa, Not Specified                                               0
# Northern Africa or Other Africa, Not Specified                              0
# Eastern Africa, Not Specified                                               0
# Australia                                                                   0
# Other US Island Areas, Oceania, Not Specified, ...                          0
#
# Mobility_status                                     Yes, same house (nonmovers)  \
# Total                                                                     43782
# N/A (person less than 1 year old/lived in same ...                        43782
# Alabama/AL                                                                    0
# Alaska/AK                                                                     0
# Arizona/AZ                                                                    0
# ...                                                                         ...
# Western Africa, Not Specified                                                 0
# Northern Africa or Other Africa, Not Specified                                0
# Eastern Africa, Not Specified                                                 0
# Australia                                                                     0
# Other US Island Areas, Oceania, Not Specified, ...                            0
#
# Mobility_status                                     No, outside US and Puerto Rico  \
# Total                                                                          133
# N/A (person less than 1 year old/lived in same ...                               0
# Alabama/AL                                                                       0
# Alaska/AK                                                                        0
# Arizona/AZ                                                                       0
# ...                                                                            ...
# Western Africa, Not Specified                                                    0
# Northern Africa or Other Africa, Not Specified                                   0
# Eastern Africa, Not Specified                                                    0
# Australia                                                                        0
# Other US Island Areas, Oceania, Not Specified, ...                               0
#
# Mobility_status                                     No, different house in US or Puerto Rico  \
# Total                                                                                   5397
# N/A (person less than 1 year old/lived in same ...                                         0
# Alabama/AL                                                                              3939
# Alaska/AK                                                                                  3
# Arizona/AZ                                                                                18
# ...                                                                                      ...
# Western Africa, Not Specified                                                              0
# Northern Africa or Other Africa, Not Specified                                             0
# Eastern Africa, Not Specified                                                              0
# Australia                                                                                  0
# Other US Island Areas, Oceania, Not Specified, ...                                         0
#
# Mobility_status                                      -> Total -> Total Alabama -> Total Doctorate degree  \
# Total                                                                                           35969
# N/A (person less than 1 year old/lived in same ...                                              31987
# Alabama/AL                                                                                       2335
# Alaska/AK                                                                                           0
# Arizona/AZ                                                                                          0
# ...                                                                                               ...
# Western Africa, Not Specified                                                                       0
# Northern Africa or Other Africa, Not Specified                                                      0
# Eastern Africa, Not Specified                                                                       0
# Australia                                                                                          10
# Other US Island Areas, Oceania, Not Specified, ...                                                  0
#
# Mobility_status                                     N/A(less than 1 year old)  \
# Total                                                                       0
# N/A (person less than 1 year old/lived in same ...                          0
# Alabama/AL                                                                  0
# Alaska/AK                                                                   0
# Arizona/AZ                                                                  0
# ...                                                                       ...
# Western Africa, Not Specified                                               0
# Northern Africa or Other Africa, Not Specified                              0
# Eastern Africa, Not Specified                                               0
# Australia                                                                   0
# Other US Island Areas, Oceania, Not Specified, ...                          0
#
# Mobility_status                                     Yes, same house (nonmovers)  \
# Total                                                                     31987
# N/A (person less than 1 year old/lived in same ...                        31987
# Alabama/AL                                                                    0
# Alaska/AK                                                                     0
# Arizona/AZ                                                                    0
# ...                                                                         ...
# Western Africa, Not Specified                                                 0
# Northern Africa or Other Africa, Not Specified                                0
# Eastern Africa, Not Specified                                                 0
# Australia                                                                     0
# Other US Island Areas, Oceania, Not Specified, ...                            0
#
# Mobility_status                                     No, outside US and Puerto Rico  \
# Total                                                                          270
# N/A (person less than 1 year old/lived in same ...                               0
# Alabama/AL                                                                       0
# Alaska/AK                                                                        0
# Arizona/AZ                                                                       0
# ...                                                                            ...
# Western Africa, Not Specified                                                    0
# Northern Africa or Other Africa, Not Specified                                   0
# Eastern Africa, Not Specified                                                    0
# Australia                                                                       10
# Other US Island Areas, Oceania, Not Specified, ...                               0
#
# Mobility_status                                     No, different house in US or Puerto Rico  \
# Total                                                                                   3712
# N/A (person less than 1 year old/lived in same ...                                         0
# Alabama/AL                                                                              2335
# Alaska/AK                                                                                  0
# Arizona/AZ                                                                                 0
# ...                                                                                      ...
# Western Africa, Not Specified                                                              0
# Northern Africa or Other Africa, Not Specified                                             0
# Eastern Africa, Not Specified                                                              0
# Australia                                                                                  0
# Other US Island Areas, Oceania, Not Specified, ...                                         0
#
# Mobility_status                                     To_State
# Total                                                Alabama
# N/A (person less than 1 year old/lived in same ...   Alabama
# Alabama/AL                                           Alabama
# Alaska/AK                                            Alabama
# Arizona/AZ                                           Alabama
# ...                                                      ...
# Western Africa, Not Specified                        Alabama
# Northern Africa or Other Africa, Not Specified       Alabama
# Eastern Africa, Not Specified                        Alabama
# Australia                                            Alabama
# Other US Island Areas, Oceania, Not Specified, ...   Alabama
#
# [110 rows x 128 columns]

# %%
list(df2.columns)
# Out:
# [' -> Total',
#  ' -> Total -> Total Alabama',
#  ' -> Total -> Total Alabama -> Total N/A (less than 3 years old)',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total No schooling completed',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Nursery school, preschool',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Kindergarten',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 1',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 2',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 3',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 4',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 5',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 6',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 7',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 8',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 9',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 10',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Grade 11',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total 12th grade - no diploma',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Regular high school diploma',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total GED or alternative credential',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Some college, but less than 1 year',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total 1 or more years of college credit, no degree',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  " -> Total -> Total Alabama -> Total Associate's degree",
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  " -> Total -> Total Alabama -> Total Bachelor's degree",
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  " -> Total -> Total Alabama -> Total Master's degree",
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  " -> Total -> Total Alabama -> Total Professional degree beyond a bachelor's degree",
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  ' -> Total -> Total Alabama -> Total Doctorate degree',
#  'N/A(less than 1 year old)',
#  'Yes, same house (nonmovers)',
#  'No, outside US and Puerto Rico',
#  'No, different house in US or Puerto Rico',
#  'To_State']

# %%
df4 = pd.concat([df2,df2,df2])

# %%
len(df4)
# Out:
# 330
