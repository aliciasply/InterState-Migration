# %%
import pandas as pd

# %%
sankey_df = pd.read_csv("../static/data/sankey.csv")
sankey_df
# Out:
#       Unnamed: 0       To_State   Origin  Total  \
# 0            110         Alaska  Alabama    227
# 1            219        Arizona  Alabama    661
# 2            328       Arkansas  Alabama    431
# 3            437     California  Alabama   2174
# 4            546       Colorado  Alabama   1463
# ...          ...            ...      ...    ...
# 2595        4956        Vermont  Wyoming      9
# 2596        5065       Virginia  Wyoming     58
# 2597        5174     Washington  Wyoming    674
# 2598        5283  West Virginia  Wyoming      0
# 2599        5392      Wisconsin  Wyoming    353
#
#       Total 12th grade - no diploma  25 years Total 12th grade - no diploma  \
# 0                                 0                                       0
# 1                                 9                                       0
# 2                                26                                       3
# 3                                41                                       0
# ...

# %%
reduced = sankey_df[["To_State", "Origin", "Total"]]
reduced
# Out:
#            To_State   Origin  Total
# 0            Alaska  Alabama    227
# 1           Arizona  Alabama    661
# 2          Arkansas  Alabama    431
# 3        California  Alabama   2174
# 4          Colorado  Alabama   1463
# ...             ...      ...    ...
# 2595        Vermont  Wyoming      9
# 2596       Virginia  Wyoming     58
# 2597     Washington  Wyoming    674
# 2598  West Virginia  Wyoming      0
# 2599      Wisconsin  Wyoming    353
#
# [2600 rows x 3 columns]

# %%
reduced.to_json("../static/data/sankey.json")
